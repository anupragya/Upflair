# %%
import os 
#The os module in Python is a built-in library that provides a portable way to interact with the underlying operating system. You can use it to perform tasks that you would normally do in a command prompt or terminal, such as managing files, navigating folders, and reading environment variables.

# %%
# pip install library name
os.getcwd()
#Returns the current working directory path as a string.
# Out:
# 'c:\\Users\\anupr\\upflair\\os'

# %%
path =r"C:\Users\anupr\upflair"

# %%
os.listdir(path) # Returns a list containing the names of files and folders in the directory.
# Out:
# ['.git',
#  '.venv',
#  'Assignmnts',
#  'aws',
#  'cborn',
#  'cbr',
#  'clarks',
#  'deep learning',
#  'git and github',
#  'lsd',
#  'machine learning',
#  'matplotlib',
#  'mlops',
#  'numpy',
#  'os',
#  'pandas',
#  'python']

# %%
os.mkdir("demo") 
# is used to create a directory at the specified path and can optionally set a permission mode. It raises a FileExistsError if the directory already exists.

# %%
os.makedirs("hello\\hii\\demo")

# %%
os.remove("C:\Users\anupr\upflair\os\demo") #method is used to delete a file at the specified path. It cannot delete directories and will raise an OSError if the given path refers to a directory. Suppose the file contained in the folder are:
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 os.remove(r"C:\Users\anupr\upflair\os\demo")
#
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\anupr\\upflair\\os\\demo'

# %%
os.rename("demo","cute")

# %%
os.chdir(r"C:\Users\anupr\upflair\os\hello\hii\demo")
os.getcwd()
# Out:
# 'C:\\Users\\anupr\\upflair\\os\\hello\\hii\\demo'

# %%
os.chdir(r"C:\Users\anupr\upflair\os")
os.getcwd()
# Out:
# 'C:\\Users\\anupr\\upflair\\os'

# %%
os.path.isdir(r"C:\Users\anupr\upflair\os")
# Out:
# True

# %%
os.path.isfile(r"C:\Users\anupr\upflair\os\cute")
# Out:
# False

# %%
os.rmdir("cute")

# %%
# os.path.isfile("file ka path")
# os.path.join(path1, path2)

# %% [markdown]
# dmart mall(class)
# product(method)
# list append
# save in a specific path
