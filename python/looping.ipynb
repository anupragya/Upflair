# %%
name ="rohit"
for x in name:
    print(x)
# Out:
# r
# o
# h
# i
# t

# %%
lst=[1,3,4,5,43,2,5533,33,5,6,3,3,22,3,3,3,3,3,3,3,3,3,]
for x in lst:
    print(x, end=" ")
# Out:
# 1 3 4 5 43 2 5533 33 5 6 3 3 22 3 3 3 3 3 3 3 3 3

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
for i in dict1:
    print(i)
# Out:
# name
# age
# address

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
for i in dict1.items():
    print(i)
# Out:
# ('name', 'oshi')
# ('age', 21)
# ('address', 'agra')

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
print("the values:")
for i in dict1.values():
    print(i)

print("\nthe keys:")
for key in dict1.keys():
    print(key)
# Out:
# the values:
# oshi
# 21
# agra
#
# the keys:
# name
# age
# address

# %%
ts={"fearless", 1989, 13,"red", "folklore"}
for i in ts:
    print(i)
# Out:
# red
# 1989
# folklore
# 13
# fearless

# %%
t1=(12, 4,4,6,2,56,32)
for i in t1:
    print(i)
# Out:
# 12
# 4
# 4
# 6
# 2
# 56
# 32

# %%
for x in range(2,11,2):
    print(x)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for x in range(10): 
    x=20
    print(x)
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
lst2=[1,4,5,3,5,3,52,5,67,89,26,44]
even=["Even numbers:"]
odd=["Odd numbers:"]
for x in lst2:
    if x%2==0:
        even.append(x)
    else:
        odd.append(x)
print(even)
print(odd)
# Out:
# ['Even numbers:', 4, 52, 26, 44]
# ['Odd numbers:', 1, 5, 3, 5, 3, 5, 67, 89]

# %%
for x in range(1,6):
    print(x, end=" ")#end is used to print in the same line
# Out:
# 1 2 3 4 5

# %%
for x in range(1,6):
    print(x**2, end=" " ) #to print square of a number
# Out:
# 1 4 9 16 25

# %%
for i in range(1,11):
    if (i%2==0):
        print(i, end=" ") # to print even num from 1 to 10
# Out:
# 2 4 6 8 10

# %%
s =0
for i in range(1,11):
    s= s+ i
print(s) #print sum of num from 1 to 10
# Out:
# 55

# %%
w="Python" #reverse this string using loop
for i in w[::-1]:
    print(i, end="")
# Out:
# nohtyP

# %%
w1="education"
lst=["a", "e", "i", "o", "u"]
vo=[]
for i in w1:
    if i in lst:
        vo.append(i)
print(vo)
print(len(vo))
# Out:
# ['e', 'u', 'a', 'i', 'o']
# 5

# %%
w1="education"
count=0
for i in w1:
    if i in "a, e, i, o, u": 
        print(i, end="")
        count+=1
print("\n", count)
# Out:
# euaio
#  5

# %%
i =1
while i<=5:
    print(i, end=" ")
    i +=1
# Out:
# 1 2 3 4 5

# %%
i=10
while i<=15:
    print(i, end=" ")
    i+=1
# Out:
# 10 11 12 13 14 15

# %%
i=1
while i<=5:
    print(i**3, end=" ")
    i+=1
# Out:
# 1 8 27 64 125

# %%
i=1
while i<=10:
    if (i%2!=0):
        print(i, end=" ")
    i+=1
# Out:
# 1 3 5 7 9

# %%
p=1
i=1
while i<6:
    p*=i
    i+=1
print(p)
# Out:
# 120
