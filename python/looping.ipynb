# %%
name ="rohit"
for x in name:
    print(x)
# Out:
# r
# o
# h
# i
# t

# %%
lst=[1,3,4,5,43,2,5533,33,5,6,3,3,22,3,3,3,3,3,3,3,3,3,]
for x in lst:
    print(x)
# Out:
# 1
# 3
# 4
# 5
# 43
# 2
# 5533
# 33
# 5
# 6
# 3
# 3
# 22
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
for i in dict1:
    print(i)
# Out:
# name
# age
# address

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
for i in dict1.items():
    print(i)
# Out:
# ('name', 'oshi')
# ('age', 21)
# ('address', 'agra')

# %%
dict1={"name": "oshi", "age":21, "address":"agra"}
print("the values:")
for i in dict1.values():
    print(i)

print("\nthe keys:")
for key in dict1.keys():
    print(key)
# Out:
# the values:
# oshi
# 21
# agra
#
# the keys:
# name
# age
# address

# %%
ts={"fearless", 1989, 13,"red", "folklore"}
for i in ts:
    print(i)
# Out:
# red
# 1989
# folklore
# 13
# fearless

# %%
t1=(12, 4,4,6,2,56,32)
for i in t1:
    print(i)
# Out:
# 12
# 4
# 4
# 6
# 2
# 56
# 32

# %%
for x in range(2,11,2):
    print(x)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for x in range(10): 
    x=20
    print(x)
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
lst2=[1,4,5,3,5,3,52,5,67,89,26,44]
even=["Even numbers:"]
odd=["Odd numbers:"]
for x in lst2:
    if x%2==0:
        even.append(x)
    else:
        odd.append(x)
print(even)
print(odd)
# Out:
# ['Even numbers:', 4, 52, 26, 44]
# ['Odd numbers:', 1, 5, 3, 5, 3, 5, 67, 89]
